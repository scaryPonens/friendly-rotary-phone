# %% [markdown]
# # ETS Python Starter
#
# This notebook uses the local package installed via `uv sync`.

# %%
from friendly_rotary_phone.ets import ETSStruct, ActiveConstraint, apply_constraint

# %%
s = ETSStruct()
c = ActiveConstraint(required_labels=['head','torso','left_arm'], required_links=[('head','torso'),('torso','left_arm')])
apply_constraint(s,c)
s

# %%
s.primitives

# %%
s.links
